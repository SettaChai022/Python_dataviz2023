# %% [markdown]
# <a href="https://colab.research.google.com/github/SettaChai022/Python_dataviz2023/blob/main/SBO_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io

# %%
df = pd.read_excel('/content/drive/MyDrive/งาน/20240905120329957-data.xlsx')
df.head(10)
# Out:
#                          Datasource             Timestamp   Value
# 0  hh:\Configuration\SBO\TT:DEOTT01  8/30/2024 8:07:26 AM  151.45
# 1  hh:\Configuration\SBO\TT:DEOTT01  8/30/2024 8:07:33 AM  151.45
# 2  hh:\Configuration\SBO\TT:DEOTT01  8/30/2024 8:08:46 AM  151.45
# 3  hh:\Configuration\SBO\TT:DEOTT01  8/30/2024 8:08:58 AM  151.45
# 4  hh:\Configuration\SBO\TT:DEOTT01  8/30/2024 8:09:02 AM  151.35
# 5  hh:\Configuration\SBO\TT:DEOTT01  8/30/2024 8:10:39 AM  151.25
# 6  hh:\Configuration\SBO\TT:DEOTT01  8/30/2024 8:10:46 AM  151.25
# 7  hh:\Configuration\SBO\TT:DEOTT01  8/30/2024 8:10:51 AM  151.25
# 8  hh:\Configuration\SBO\TT:DEOTT01  8/30/2024 8:11:48 AM  151.15
# 9  hh:\Configuration\SBO\TT:DEOTT01  8/30/2024 8:13:19 AM  151.15

# %%
df.shape
# Out:
# (31119, 3)

# %%
df.describe()
# Out:
#               Value
# count  31119.000000
# mean     210.642841
# std       72.166706
# min        0.000000
# 25%      170.100000
# 50%      192.300000
# 75%      209.220000
# max      404.430000

# %%
df.columns
# Out:
# Index(['Datasource', 'Timestamp', 'Value'], dtype='object')

# %%
# แปลงข้อมูลโดยใช้ pivot

df_pivot = df.pivot_table(index='Timestamp', columns='Datasource', values='Value', aggfunc='first').reset_index()
print(df_pivot)
# Out:
# Datasource              Timestamp  hh:\Configuration\SBO\TT:DEOTT01  \
# 0           8/30/2024 10:00:06 PM                               NaN
# 1           8/30/2024 10:00:08 AM                            157.96
# 2           8/30/2024 10:00:09 AM                               NaN
# 3           8/30/2024 10:00:12 PM                               NaN
# 4           8/30/2024 10:00:14 AM                               NaN
# ...                           ...                               ...
# 24971        8/31/2024 8:06:55 AM                               NaN
# 24972        8/31/2024 8:06:58 AM                               NaN
# 24973        8/31/2024 8:07:04 AM                               NaN
# 24974        8/31/2024 8:07:07 AM                               NaN
# 24975        8/31/2024 8:07:08 AM                               NaN
#
# Datasource  hh:\Configuration\SBO\TT:DEOTT02  \
# 0                                        NaN
# 1                                        NaN
# ...

# %%
# !pip install openpyxl

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path ='/content/drive/MyDrive/งาน/output.xlsx'
df_pivot.to_excel(file_path, index=False)
